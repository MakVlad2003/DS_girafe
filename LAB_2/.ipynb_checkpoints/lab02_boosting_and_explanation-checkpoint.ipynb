# %% [markdown]
# # <a href="https://girafe.ai/" target="_blank" rel="noopener noreferrer"><img src="https://raw.githubusercontent.com/girafe-ai/ml-course/7096a5df4cada5ee651be1e3215c2f7fb8a7e0bf/logo_margin.svg" alt="girafe-ai logo" width="150px" align="left"></a> [ml-basic course](https://github.com/girafe-ai/ml-course) <a class="tocSkip">
#
# # Lab assignment №1, part 2
# ## Gradient boosting on temporal data and feature importances

# %% [markdown]
# Today we will work with Gradient Boosting library. It is one of the most popular models these days that shows both great quality and performance.
#
# Choises for library are:
#
# * [LightGBM](https://github.com/Microsoft/LightGBM) by Microsoft. Handful and fast.
# * [Catboost](https://github.com/catboost/catboost) by Yandex. Tuned to deal well with categorical features.
# * [xgboost](https://github.com/dmlc/xgboost) by dlmc. The most famous framework which got very popular on kaggle.
#
# **Dataset**
#
# By default we will work with widely known [Human Actividy Recognition (HAR) dataset](https://archive.ics.uci.edu/dataset/240/human+activity+recognition+using+smartphones). Data is available at UCI repository.
#
# There are available both raw and preprocessed datasets. This time we will use the preprocessed one.
# Some simple preprocessing is done for you.
#
# If you want more interpretable data, you can take [Wine quality dataset](https://archive.ics.uci.edu/dataset/186/wine+quality) (see details below).
#
# Your __ultimate target is to get familiar with one of the frameworks above__ and achieve at least 90% accuracy on test dataset and try to get some useful insights on the features the model paid attention to.
#
# _Despite the main language of this notebook is English, feel free to write your thoughts in Russian._

# %% [markdown]
# ## Part 0. Downloading and preprocessing
#
# The preprocessing is done for you. Let's take a look at the data:

# %%
# Download and unpack dataset from UCI
# !wget -nc https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# !unzip -u "UCI HAR Dataset.zip" "UCI HAR Dataset/train/X_train.txt" "UCI HAR Dataset/train/y_train.txt" \
"UCI HAR Dataset/test/X_test.txt" "UCI HAR Dataset/test/y_test.txt" "UCI HAR Dataset/activity_labels.txt"
# Out:
# --2024-11-16 15:47:03--  https://archive.ics.uci.edu/ml/machine-learning-databases/00240/UCI%20HAR%20Dataset.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified
# Saving to: ‘UCI HAR Dataset.zip’
#
# UCI HAR Dataset.zip     [      <=>           ]  58.17M  53.8MB/s    in 1.1s
#
# 2024-11-16 15:47:04 (53.8 MB/s) - ‘UCI HAR Dataset.zip’ saved [60999314]
#
# Archive:  UCI HAR Dataset.zip
#   inflating: UCI HAR Dataset/activity_labels.txt
#   inflating: UCI HAR Dataset/test/X_test.txt
#   inflating: UCI HAR Dataset/test/y_test.txt
#   inflating: UCI HAR Dataset/train/X_train.txt
#   inflating: UCI HAR Dataset/train/y_train.txt

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X_train = np.genfromtxt("UCI HAR Dataset/train/X_train.txt")
y_train = np.genfromtxt("UCI HAR Dataset/train/y_train.txt")
print(f"Train set: {X_train.shape}, {y_train.shape}")

X_test = np.genfromtxt("UCI HAR Dataset/test/X_test.txt")
y_test = np.genfromtxt("UCI HAR Dataset/test/y_test.txt")
print(f"Test set: {X_test.shape}, {y_test.shape}")

n_features = X_train.shape[1]
# Out:
# Train set: (7352, 561), (7352,)
# Test set: (2947, 561), (2947,)

# %%
activity_labels = {}
with open("UCI HAR Dataset/activity_labels.txt", "r") as file:
    for line in file:
        label, name = line.strip().split(" ")
        activity_labels[int(label)] = name

activity_labels
# Out:
# {1: 'WALKING',
#  2: 'WALKING_UPSTAIRS',
#  3: 'WALKING_DOWNSTAIRS',
#  4: 'SITTING',
#  5: 'STANDING',
#  6: 'LAYING'}

# %% [markdown]
# Let's normalize data

# %%
data_mean = X_train.mean(axis=0)
data_std = X_train.std(axis=0)

X_train = (X_train - data_mean) / data_std
X_test = (X_test - data_mean) / data_std

# %% [markdown]
# The dataset has some duplicating features. Let's remove them

# %%
# fmt: off
duplicating_columns = (
    205, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 231, 244, 257, 507, 520, 533, 546,
)
# fmt: on

duplicating_mask = np.isin(range(n_features), duplicating_columns)

# %%
X_train_unique = X_train[:, ~duplicating_mask]
X_test_unique = X_test[:, ~duplicating_mask]

X_train_unique.shape, X_test_unique.shape
# Out:
# ((7352, 540), (2947, 540))

# %% [markdown]
# PCA could be useful in this case. E.g.

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(0.99)

X_train_pca = pca.fit_transform(X_train_unique)
X_test_pca = pca.transform(X_test_unique)

X_train_pca.shape, X_test_pca.shape
# Out:
# ((7352, 179), (2947, 179))

# %%
plt.scatter(X_train_pca[:1000, 0], X_train_pca[:1000, 1], c=y_train[:1000])
plt.grid()
plt.xlabel("Principal component 1")
plt.ylabel("Principal component 2")
# Out:
# Text(0, 0.5, 'Principal component 2')

# %%
plt.scatter(X_train_pca[:1000, 3], X_train_pca[:1000, 4], c=y_train[:1000])
plt.grid()
plt.xlabel("Principal component 4")
plt.ylabel("Principal component 5")
# Out:
# Text(0, 0.5, 'Principal component 5')

# %% [markdown]
# ### Alternative dataset: Wine quality
#
# Please, take this dataset if you are sure you can preprocess it yourself and ready to work with it's features and results, so it is done on your risk.
#
# However you will have interpretable features which can be analysed with shap in last part

# %%
# !pip install ucimlrepo
# Out:
# Collecting ucimlrepo
#   Downloading ucimlrepo-0.0.7-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ucimlrepo) (2.2.2)
# Requirement already satisfied: certifi>=2020.12.5 in /usr/local/lib/python3.10/dist-packages (from ucimlrepo) (2024.8.30)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->ucimlrepo) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.16.0)
# Downloading ucimlrepo-0.0.7-py3-none-any.whl (8.0 kB)
# Installing collected packages: ucimlrepo
# Successfully installed ucimlrepo-0.0.7

# %%
import ucimlrepo as uci

# %%
dataset = uci.fetch_ucirepo(id=186)

print(dataset.metadata.name, '\n')
print(dataset.metadata.abstract, '\n')
print(dataset.metadata.additional_info.summary, '\n')
# Out:
# Wine Quality
#
# Two datasets are included, related to red and white vinho verde wine samples, from the north of Portugal. The goal is to model wine quality based on physicochemical tests (see [Cortez et al., 2009], http://www3.dsi.uminho.pt/pcortez/wine/).
#
# The two datasets are related to red and white variants of the Portuguese "Vinho Verde" wine. For more details, consult: http://www.vinhoverde.pt/en/ or the reference [Cortez et al., 2009].  Due to privacy and logistic issues, only physicochemical (inputs) and sensory (the output) variables are available (e.g. there is no data about grape types, wine brand, wine selling price, etc.).
#
# These datasets can be viewed as classification or regression tasks.  The classes are ordered and not balanced (e.g. there are many more normal wines than excellent or poor ones). Outlier detection algorithms could be used to detect the few excellent or poor wines. Also, we are not sure if all input variables are relevant. So it could be interesting to test feature selection methods.

# %% [markdown]
# ## Part 1. Fit the model.

# %% [markdown]
# Despite optimal parameters (e.g. for xgboost) can be found on the web, we still want you to approximate them by yourself.
#
# In this part just check some (3-5) sets of hyperparameters by hand.

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.9 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
# Example: https://rpubs.com/burakh/har_xgb

from sklearn.metrics import accuracy_score

from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# %% [markdown]
# Напишем Функцию для тренировки модели и вывода метрик:

# %%
def train_and_evaluate(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    acc = accuracy_score(y_test, y_pred)

    return acc

# %% [markdown]
# ### **LightGBM**

# %%
print("Testing LightGBM with different hyperparameters:")

lgbm_params_list = [
    {"n_estimators": 100, "learning_rate": 0.1, "max_depth": 7, "random_state": 42},
    {"n_estimators": 150, "learning_rate": 0.05, "max_depth": 9, "random_state": 42},
    {"n_estimators": 200, "learning_rate": 0.1, "max_depth": 5, "random_state": 42},
    {"n_estimators": 300, "learning_rate": 0.05, "max_depth": 6, "random_state": 42},
    {"n_estimators": 250, "learning_rate": 0.2, "max_depth": 4, "random_state": 42},
]

for i, params in enumerate(lgbm_params_list, 1):
    print(f"\nSet {i}: {params}")

    lgbm_model = LGBMClassifier(**params, verbose=-1)
    acc = train_and_evaluate(lgbm_model, X_train_pca, y_train, X_test_pca, y_test)

    print(f"Accuracy: {acc:.4f}")
# Out:
# Testing LightGBM with different hyperparameters:
#
# Set 1: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7, 'random_state': 42}
# Accuracy: 0.9091
#
# Set 2: {'n_estimators': 150, 'learning_rate': 0.05, 'max_depth': 9, 'random_state': 42}
# Accuracy: 0.9053
#
# Set 3: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5, 'random_state': 42}
# Accuracy: 0.9192
#
# Set 4: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 6, 'random_state': 42}
# Accuracy: 0.9125
#
# Set 5: {'n_estimators': 250, 'learning_rate': 0.2, 'max_depth': 4, 'random_state': 42}
# Accuracy: 0.9287

# %% [markdown]
# ### **CatBoost**

# %%
print("Testing CatBoost with different hyperparameters:")

catboost_params_list = [
    {"iterations": 100, "learning_rate": 0.1, "depth": 7, "verbose": False, "random_seed": 42},
    {"iterations": 150, "learning_rate": 0.05, "depth": 9, "verbose": False, "random_seed": 42},
    {"iterations": 200, "learning_rate": 0.1, "depth": 5, "verbose": False, "random_seed": 42},
    {"iterations": 300, "learning_rate": 0.05, "depth": 6, "verbose": False, "random_seed": 42},
    {"iterations": 250, "learning_rate": 0.2, "depth": 4, "verbose": False, "random_seed": 42},
]

for i, params in enumerate(catboost_params_list, 1):
    print(f"\nSet {i}: {params}")

    catboost_model = CatBoostClassifier(**params)
    acc = train_and_evaluate(catboost_model, X_train_pca, y_train, X_test_pca, y_test)

    print(f"Accuracy: {acc:.4f}")
# Out:
# Testing CatBoost with different hyperparameters:
#
# Set 1: {'iterations': 100, 'learning_rate': 0.1, 'depth': 7, 'verbose': False, 'random_seed': 42}
# Accuracy: 0.8982
#
# Set 2: {'iterations': 150, 'learning_rate': 0.05, 'depth': 9, 'verbose': False, 'random_seed': 42}
# Accuracy: 0.8914
#
# Set 3: {'iterations': 200, 'learning_rate': 0.1, 'depth': 5, 'verbose': False, 'random_seed': 42}
# Accuracy: 0.9145
#
# Set 4: {'iterations': 300, 'learning_rate': 0.05, 'depth': 6, 'verbose': False, 'random_seed': 42}
# Accuracy: 0.9094
#
# Set 5: {'iterations': 250, 'learning_rate': 0.2, 'depth': 4, 'verbose': False, 'random_seed': 42}
# Accuracy: 0.9277

# %% [markdown]
# ### **XGBoost**

# %%
import xgboost as xgb

# %%
print("Testing XGBoost with different hyperparameters:")

xgboost_params_list = [
    {"n_estimators": 100, "learning_rate": 0.1, "max_depth": 7, "random_state": 42, "eval_metric": "logloss"},
    {"n_estimators": 150, "learning_rate": 0.05, "max_depth": 9, "random_state": 42, "eval_metric": "logloss"},
    {"n_estimators": 200, "learning_rate": 0.1, "max_depth": 5, "random_state": 42, "eval_metric": "logloss"},
    {"n_estimators": 300, "learning_rate": 0.05, "max_depth": 6, "random_state": 42, "eval_metric": "logloss"},
    {"n_estimators": 250, "learning_rate": 0.2, "max_depth": 4, "random_state": 42, "eval_metric": "logloss"},
]

dtrain = xgb.DMatrix(X_train_pca, label=y_train)
dtest = xgb.DMatrix(X_test_pca, label=y_test)

for i, params in enumerate(xgboost_params_list, 1):
    print(f"\nSet {i}: {params}")

    num_rounds = params.pop("n_estimators")
    model = xgb.train(params, dtrain, num_boost_round=num_rounds)

    y_pred = model.predict(dtest)
    y_pred = [int(pred) for pred in y_pred]
    accuracy = accuracy_score(y_test, y_pred)

    print(f"Accuracy: {accuracy:.4f}")
# Out:
# Testing XGBoost with different hyperparameters:
#
# Set 1: {'n_estimators': 100, 'learning_rate': 0.1, 'max_depth': 7, 'random_state': 42, 'eval_metric': 'logloss'}
# Accuracy: 0.4954
#
# Set 2: {'n_estimators': 150, 'learning_rate': 0.05, 'max_depth': 9, 'random_state': 42, 'eval_metric': 'logloss'}
# Accuracy: 0.4567
#
# Set 3: {'n_estimators': 200, 'learning_rate': 0.1, 'max_depth': 5, 'random_state': 42, 'eval_metric': 'logloss'}
# Accuracy: 0.5327
#
# Set 4: {'n_estimators': 300, 'learning_rate': 0.05, 'max_depth': 6, 'random_state': 42, 'eval_metric': 'logloss'}
# Accuracy: 0.5256
#
# Set 5: {'n_estimators': 250, 'learning_rate': 0.2, 'max_depth': 4, 'random_state': 42, 'eval_metric': 'logloss'}
# Accuracy: 0.5402

# %% [markdown]
# **Выводы:**
#
#   - **LightGBM**:
#
#   Наилучший результат показал Набор 5 (n_estimators=250, learning_rate=0.2, max_depth=4), с точностью 0.9287.
#
#   - **CatBoost:**
#
#   Наилучший результат показал также Набор 5 (iterations=250, learning_rate=0.2, depth=4), с точностью 0.9277.
#
#   - **XGBoost:**
#
#   Точность XGBoost значительно ниже, чем у LightGBM и CatBoost, и наилучший результат в Наборе 5 составляет 0.5402.
#
# **Оптимальная модель**:
#
# Из всех моделей LightGBM (Набор 5) показал наилучшие результаты с точностью 0.9287, что делает его наиболее подходящим для дальнейшего использования.

# %% [markdown]
# ## Part 2. Use hyper parameter tuning system
#
# Use [optuna](https://optuna.org/), [hyperopt](http://hyperopt.github.io/hyperopt/) or any other zero order optimizer to find optimal hyper param set.

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-4.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting alembic>=1.5.0 (from optuna)
#   Downloading alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from optuna) (24.2)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from optuna) (2.0.36)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from optuna) (4.66.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from optuna) (6.0.2)
# Collecting Mako (from alembic>=1.5.0->optuna)
#   Downloading Mako-1.3.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from alembic>=1.5.0->optuna) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.1.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.10/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.2)
# Downloading optuna-4.1.0-py3-none-any.whl (364 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.4/364.4 kB 14.3 MB/s eta 0:00:00
# Downloading alembic-1.14.0-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.5/233.5 kB 11.6 MB/s eta 0:00:00
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Downloading Mako-1.3.6-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: Mako, colorlog, alembic, optuna
# Successfully installed Mako-1.3.6 alembic-1.14.0 colorlog-6.9.0 optuna-4.1.0

# %%
from sklearn.model_selection import train_test_split
import optuna
import lightgbm as lgb
import pandas as pd

# %%
X_train_opt, X_val_opt, y_train_opt, y_val_opt = train_test_split(X_train_pca, y_train, test_size=0.2, random_state=42)

# Функция оптимизации для Optuna
def objective(trial):
    params = {
        'boosting_type': 'gbdt',
        'num_leaves': trial.suggest_int('num_leaves', 31, 256),
        'max_depth': trial.suggest_int('max_depth', 3, 12),
        'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
        'n_estimators': trial.suggest_int('n_estimators', 50, 500),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 100),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
    }

    model = lgb.LGBMClassifier(**params, verbose=-1)
    model.fit(X_train_opt, y_train_opt)

    y_pred = model.predict(X_val_opt)
    accuracy = accuracy_score(y_val_opt, y_pred)

    return accuracy

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

print(f"Best parameters: {study.best_params}")
print(f"Best accuracy: {study.best_value:.4f}")

df_trials = pd.DataFrame(study.trials_dataframe())
df_trials_sorted = df_trials.sort_values(by="value", ascending=False)

print("\nDetailed results of all trials (sorted by accuracy):")
print(df_trials_sorted[['number', 'value',
                        'params_num_leaves',
                        'params_max_depth',
                        'params_learning_rate',
                        'params_n_estimators',
                        'params_min_child_samples',
                        'params_subsample',
                        'params_colsample_bytree']].head(10))
# Out:
# [I 2024-11-16 15:54:48,311] A new study created in memory with name: no-name-a7ad2d70-a7ad-4576-923c-a2419ad4184e
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:54:54,881] Trial 0 finished with value: 0.9632902787219578 and parameters: {'num_leaves': 223, 'max_depth': 4, 'learning_rate': 0.116042076848697, 'n_estimators': 139, 'min_child_samples': 34, 'subsample': 0.9293287594182547, 'colsample_bytree': 0.6882165463092829}. Best is trial 0 with value: 0.9632902787219578.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:55:09,165] Trial 1 finished with value: 0.9632902787219578 and parameters: {'num_leaves': 149, 'max_depth': 9, 'learning_rate': 0.19976628880672528, 'n_estimators': 500, 'min_child_samples': 40, 'subsample': 0.5819758785109455, 'colsample_bytree': 0.5819177586619816}. Best is trial 0 with value: 0.9632902787219578.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:55:25,360] Trial 2 finished with value: 0.9653297076818491 and parameters: {'num_leaves': 215, 'max_depth': 7, 'learning_rate': 0.18553784935908096, 'n_estimators': 297, 'min_child_samples': 52, 'subsample': 0.5585704671393807, 'colsample_bytree': 0.9553330112635079}. Best is trial 2 with value: 0.9653297076818491.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:55:30,248] Trial 3 finished with value: 0.9551325628823929 and parameters: {'num_leaves': 54, 'max_depth': 3, 'learning_rate': 0.08694910461462423, 'n_estimators': 146, 'min_child_samples': 13, 'subsample': 0.5693660305256933, 'colsample_bytree': 0.8056300397795197}. Best is trial 2 with value: 0.9653297076818491.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:55:54,031] Trial 4 finished with value: 0.9673691366417403 and parameters: {'num_leaves': 82, 'max_depth': 5, 'learning_rate': 0.04917171845609286, 'n_estimators': 325, 'min_child_samples': 29, 'subsample': 0.5976190490294322, 'colsample_bytree': 0.8130997524641141}. Best is trial 4 with value: 0.9673691366417403.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:56:17,868] Trial 5 finished with value: 0.9687287559483345 and parameters: {'num_leaves': 128, 'max_depth': 10, 'learning_rate': 0.07406314017872766, 'n_estimators': 243, 'min_child_samples': 76, 'subsample': 0.5271996012913578, 'colsample_bytree': 0.6022791456134552}. Best is trial 5 with value: 0.9687287559483345.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:56:26,347] Trial 6 finished with value: 0.9714479945615228 and parameters: {'num_leaves': 140, 'max_depth': 3, 'learning_rate': 0.28888367604583975, 'n_estimators': 420, 'min_child_samples': 73, 'subsample': 0.8243936493102992, 'colsample_bytree': 0.6073866708846567}. Best is trial 6 with value: 0.9714479945615228.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:56:47,479] Trial 7 finished with value: 0.9700883752549286 and parameters: {'num_leaves': 55, 'max_depth': 9, 'learning_rate': 0.07448986110464996, 'n_estimators': 382, 'min_child_samples': 89, 'subsample': 0.9182797000133045, 'colsample_bytree': 0.5153518053657589}. Best is trial 6 with value: 0.9714479945615228.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:56:54,850] Trial 8 finished with value: 0.947654656696125 and parameters: {'num_leaves': 55, 'max_depth': 6, 'learning_rate': 0.0829252240189543, 'n_estimators': 56, 'min_child_samples': 28, 'subsample': 0.9505997892726776, 'colsample_bytree': 0.904501057497015}. Best is trial 6 with value: 0.9714479945615228.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:57:29,851] Trial 9 finished with value: 0.9653297076818491 and parameters: {'num_leaves': 166, 'max_depth': 9, 'learning_rate': 0.07240924366453146, 'n_estimators': 481, 'min_child_samples': 81, 'subsample': 0.5206175949480347, 'colsample_bytree': 0.7969410641067749}. Best is trial 6 with value: 0.9714479945615228.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:57:39,869] Trial 10 finished with value: 0.9415363698164514 and parameters: {'num_leaves': 107, 'max_depth': 3, 'learning_rate': 0.017500196638592473, 'n_estimators': 407, 'min_child_samples': 70, 'subsample': 0.7791607885792242, 'colsample_bytree': 0.677705201639555}. Best is trial 6 with value: 0.9714479945615228.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:58:12,480] Trial 11 finished with value: 0.9653297076818491 and parameters: {'num_leaves': 181, 'max_depth': 12, 'learning_rate': 0.02526682625785878, 'n_estimators': 390, 'min_child_samples': 100, 'subsample': 0.8419903638718188, 'colsample_bytree': 0.5010660305982851}. Best is trial 6 with value: 0.9714479945615228.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:58:40,433] Trial 12 finished with value: 0.9510537049626104 and parameters: {'num_leaves': 36, 'max_depth': 11, 'learning_rate': 0.010019489856870298, 'n_estimators': 401, 'min_child_samples': 98, 'subsample': 0.8455383251661053, 'colsample_bytree': 0.5062970158031503}. Best is trial 6 with value: 0.9714479945615228.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:58:49,826] Trial 13 finished with value: 0.9673691366417403 and parameters: {'num_leaves': 252, 'max_depth': 8, 'learning_rate': 0.2936194440150414, 'n_estimators': 360, 'min_child_samples': 62, 'subsample': 0.7021596190506346, 'colsample_bytree': 0.6002393994194419}. Best is trial 6 with value: 0.9714479945615228.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:59:24,738] Trial 14 finished with value: 0.9626104690686608 and parameters: {'num_leaves': 96, 'max_depth': 7, 'learning_rate': 0.0358772976020921, 'n_estimators': 434, 'min_child_samples': 89, 'subsample': 0.9915551608317716, 'colsample_bytree': 0.6672471157359617}. Best is trial 6 with value: 0.9714479945615228.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:59:32,971] Trial 15 finished with value: 0.9721278042148198 and parameters: {'num_leaves': 127, 'max_depth': 5, 'learning_rate': 0.16012048039726579, 'n_estimators': 270, 'min_child_samples': 86, 'subsample': 0.8691732610096221, 'colsample_bytree': 0.5531722509755044}. Best is trial 15 with value: 0.9721278042148198.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:59:39,846] Trial 16 finished with value: 0.9680489462950373 and parameters: {'num_leaves': 131, 'max_depth': 5, 'learning_rate': 0.2820707304750419, 'n_estimators': 245, 'min_child_samples': 58, 'subsample': 0.7027450235428883, 'colsample_bytree': 0.5697456182660163}. Best is trial 15 with value: 0.9721278042148198.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:59:46,642] Trial 17 finished with value: 0.9687287559483345 and parameters: {'num_leaves': 188, 'max_depth': 4, 'learning_rate': 0.1606087584341269, 'n_estimators': 188, 'min_child_samples': 68, 'subsample': 0.8317511795215444, 'colsample_bytree': 0.7276649394783312}. Best is trial 15 with value: 0.9721278042148198.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 15:59:58,205] Trial 18 finished with value: 0.9687287559483345 and parameters: {'num_leaves': 151, 'max_depth': 5, 'learning_rate': 0.1320056320667679, 'n_estimators': 302, 'min_child_samples': 81, 'subsample': 0.7609489059659132, 'colsample_bytree': 0.6327023941261447}. Best is trial 15 with value: 0.9721278042148198.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:00:03,823] Trial 19 finished with value: 0.9687287559483345 and parameters: {'num_leaves': 110, 'max_depth': 3, 'learning_rate': 0.22316213439062443, 'n_estimators': 250, 'min_child_samples': 49, 'subsample': 0.8788087317906422, 'colsample_bytree': 0.5547074743788686}. Best is trial 15 with value: 0.9721278042148198.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:00:20,716] Trial 20 finished with value: 0.9700883752549286 and parameters: {'num_leaves': 82, 'max_depth': 6, 'learning_rate': 0.11577757773698755, 'n_estimators': 339, 'min_child_samples': 70, 'subsample': 0.6569378203374698, 'colsample_bytree': 0.7404906641344057}. Best is trial 15 with value: 0.9721278042148198.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:00:51,351] Trial 21 finished with value: 0.9673691366417403 and parameters: {'num_leaves': 70, 'max_depth': 9, 'learning_rate': 0.05259246085547182, 'n_estimators': 456, 'min_child_samples': 88, 'subsample': 0.8895825984907303, 'colsample_bytree': 0.5431792637010459}. Best is trial 15 with value: 0.9721278042148198.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:01:00,684] Trial 22 finished with value: 0.9755268524813052 and parameters: {'num_leaves': 117, 'max_depth': 4, 'learning_rate': 0.15332096295468947, 'n_estimators': 364, 'min_child_samples': 89, 'subsample': 0.7953343128961083, 'colsample_bytree': 0.5286009853818954}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:01:12,309] Trial 23 finished with value: 0.9721278042148198 and parameters: {'num_leaves': 125, 'max_depth': 4, 'learning_rate': 0.1481135328740105, 'n_estimators': 436, 'min_child_samples': 81, 'subsample': 0.7920113117119426, 'colsample_bytree': 0.6319506573072359}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:01:22,905] Trial 24 finished with value: 0.9721278042148198 and parameters: {'num_leaves': 120, 'max_depth': 4, 'learning_rate': 0.14662636046458202, 'n_estimators': 348, 'min_child_samples': 93, 'subsample': 0.7896213966764383, 'colsample_bytree': 0.6459618871840406}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:01:35,695] Trial 25 finished with value: 0.9707681849082257 and parameters: {'num_leaves': 163, 'max_depth': 6, 'learning_rate': 0.10860720061476546, 'n_estimators': 283, 'min_child_samples': 81, 'subsample': 0.7010828183248574, 'colsample_bytree': 0.5481788281741722}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:01:41,615] Trial 26 finished with value: 0.9707681849082257 and parameters: {'num_leaves': 97, 'max_depth': 4, 'learning_rate': 0.20253921777024525, 'n_estimators': 199, 'min_child_samples': 94, 'subsample': 0.7440441926290703, 'colsample_bytree': 0.6303900097450496}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:01:57,253] Trial 27 finished with value: 0.9666893269884432 and parameters: {'num_leaves': 120, 'max_depth': 5, 'learning_rate': 0.100148334900861, 'n_estimators': 366, 'min_child_samples': 85, 'subsample': 0.8021550969368711, 'colsample_bytree': 0.7097469247528689}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:02:07,606] Trial 28 finished with value: 0.9666893269884432 and parameters: {'num_leaves': 179, 'max_depth': 6, 'learning_rate': 0.16520298757905955, 'n_estimators': 324, 'min_child_samples': 62, 'subsample': 0.8783272596894255, 'colsample_bytree': 0.5358659273841391}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:02:27,324] Trial 29 finished with value: 0.9653297076818491 and parameters: {'num_leaves': 203, 'max_depth': 4, 'learning_rate': 0.03904626238915366, 'n_estimators': 452, 'min_child_samples': 76, 'subsample': 0.7491963072494796, 'colsample_bytree': 0.7720806863898713}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:02:33,670] Trial 30 finished with value: 0.9694085656016316 and parameters: {'num_leaves': 159, 'max_depth': 4, 'learning_rate': 0.1275060119532987, 'n_estimators': 212, 'min_child_samples': 95, 'subsample': 0.9417586811168208, 'colsample_bytree': 0.5789395792488559}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:02:44,157] Trial 31 finished with value: 0.9687287559483345 and parameters: {'num_leaves': 119, 'max_depth': 4, 'learning_rate': 0.14553509324502295, 'n_estimators': 337, 'min_child_samples': 94, 'subsample': 0.7845596887096088, 'colsample_bytree': 0.6483829699565443}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:02:54,441] Trial 32 finished with value: 0.9666893269884432 and parameters: {'num_leaves': 139, 'max_depth': 5, 'learning_rate': 0.2128686481985633, 'n_estimators': 370, 'min_child_samples': 85, 'subsample': 0.8107244768375534, 'colsample_bytree': 0.7032649345620634}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:03:06,100] Trial 33 finished with value: 0.9700883752549286 and parameters: {'num_leaves': 101, 'max_depth': 4, 'learning_rate': 0.15948812584101926, 'n_estimators': 498, 'min_child_samples': 93, 'subsample': 0.7255378854253687, 'colsample_bytree': 0.652386787924089}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:03:11,826] Trial 34 finished with value: 0.9694085656016316 and parameters: {'num_leaves': 119, 'max_depth': 3, 'learning_rate': 0.09824253321205234, 'n_estimators': 265, 'min_child_samples': 100, 'subsample': 0.6489903849092888, 'colsample_bytree': 0.6208729473256673}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:03:23,030] Trial 35 finished with value: 0.9673691366417403 and parameters: {'num_leaves': 84, 'max_depth': 7, 'learning_rate': 0.18112517979793588, 'n_estimators': 305, 'min_child_samples': 44, 'subsample': 0.8538865282061547, 'colsample_bytree': 0.5760989479420906}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:03:35,615] Trial 36 finished with value: 0.9666893269884432 and parameters: {'num_leaves': 147, 'max_depth': 5, 'learning_rate': 0.23247190653361732, 'n_estimators': 438, 'min_child_samples': 78, 'subsample': 0.7915330586975294, 'colsample_bytree': 0.8916429654426684}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:03:42,038] Trial 37 finished with value: 0.9694085656016316 and parameters: {'num_leaves': 129, 'max_depth': 3, 'learning_rate': 0.13483513800064317, 'n_estimators': 347, 'min_child_samples': 85, 'subsample': 0.9106477332428597, 'colsample_bytree': 0.527935078128817}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:03:49,851] Trial 38 finished with value: 0.9632902787219578 and parameters: {'num_leaves': 136, 'max_depth': 5, 'learning_rate': 0.06794126090644594, 'n_estimators': 152, 'min_child_samples': 90, 'subsample': 0.6585094256692421, 'colsample_bytree': 0.6034617335792708}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:03:52,066] Trial 39 finished with value: 0.9598912304554724 and parameters: {'num_leaves': 114, 'max_depth': 3, 'learning_rate': 0.24808572417683517, 'n_estimators': 61, 'min_child_samples': 67, 'subsample': 0.8582848574077009, 'colsample_bytree': 0.9978090265429944}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:04:16,482] Trial 40 finished with value: 0.9680489462950373 and parameters: {'num_leaves': 88, 'max_depth': 6, 'learning_rate': 0.06289042927062008, 'n_estimators': 320, 'min_child_samples': 35, 'subsample': 0.7710725469182709, 'colsample_bytree': 0.6875411642337602}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:04:26,140] Trial 41 finished with value: 0.9700883752549286 and parameters: {'num_leaves': 144, 'max_depth': 4, 'learning_rate': 0.1870493542438305, 'n_estimators': 421, 'min_child_samples': 77, 'subsample': 0.8182292140765228, 'colsample_bytree': 0.5961872551594556}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:04:35,369] Trial 42 finished with value: 0.9700883752549286 and parameters: {'num_leaves': 153, 'max_depth': 3, 'learning_rate': 0.08842281877046242, 'n_estimators': 463, 'min_child_samples': 72, 'subsample': 0.8153902464281594, 'colsample_bytree': 0.564973542587653}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:04:43,625] Trial 43 finished with value: 0.9714479945615228 and parameters: {'num_leaves': 129, 'max_depth': 4, 'learning_rate': 0.24481451037448634, 'n_estimators': 415, 'min_child_samples': 82, 'subsample': 0.7281903602872141, 'colsample_bytree': 0.6154141517388872}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:04:51,112] Trial 44 finished with value: 0.9707681849082257 and parameters: {'num_leaves': 71, 'max_depth': 3, 'learning_rate': 0.2976675487756369, 'n_estimators': 381, 'min_child_samples': 12, 'subsample': 0.9020421917544422, 'colsample_bytree': 0.6536077207557583}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:04:58,952] Trial 45 finished with value: 0.9707681849082257 and parameters: {'num_leaves': 173, 'max_depth': 4, 'learning_rate': 0.17594729345236437, 'n_estimators': 398, 'min_child_samples': 90, 'subsample': 0.8648710650045224, 'colsample_bytree': 0.5228924233067601}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:05:09,015] Trial 46 finished with value: 0.9721278042148198 and parameters: {'num_leaves': 106, 'max_depth': 3, 'learning_rate': 0.14047682792707228, 'n_estimators': 476, 'min_child_samples': 72, 'subsample': 0.8305517056825356, 'colsample_bytree': 0.5888585431943072}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:05:27,250] Trial 47 finished with value: 0.9700883752549286 and parameters: {'num_leaves': 102, 'max_depth': 5, 'learning_rate': 0.11989607014909774, 'n_estimators': 491, 'min_child_samples': 74, 'subsample': 0.8328498963623839, 'colsample_bytree': 0.8429879019454243}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:05:42,543] Trial 48 finished with value: 0.9666893269884432 and parameters: {'num_leaves': 71, 'max_depth': 8, 'learning_rate': 0.14663748086035247, 'n_estimators': 463, 'min_child_samples': 86, 'subsample': 0.9729086374394885, 'colsample_bytree': 0.589968918850296}. Best is trial 22 with value: 0.9755268524813052.
# <ipython-input-28-69029e73c6ae>:9: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'learning_rate': trial.suggest_loguniform('learning_rate', 0.01, 0.3),
# [I 2024-11-16 16:05:47,502] Trial 49 finished with value: 0.9673691366417403 and parameters: {'num_leaves': 109, 'max_depth': 3, 'learning_rate': 0.08589903959835728, 'n_estimators': 275, 'min_child_samples': 97, 'subsample': 0.7950485579308434, 'colsample_bytree': 0.5027287714284381}. Best is trial 22 with value: 0.9755268524813052.
# Best parameters: {'num_leaves': 117, 'max_depth': 4, 'learning_rate': 0.15332096295468947, 'n_estimators': 364, 'min_child_samples': 89, 'subsample': 0.7953343128961083, 'colsample_bytree': 0.5286009853818954}
# Best accuracy: 0.9755
#
# Detailed results of all trials (sorted by accuracy):
#     number     value  params_num_leaves  params_max_depth  \
# 22      22  0.975527                117                 4
# 15      15  0.972128                127                 5
# 46      46  0.972128                106                 3
# 24      24  0.972128                120                 4
# 23      23  0.972128                125                 4
# 43      43  0.971448                129                 4
# 6        6  0.971448                140                 3
# 25      25  0.970768                163                 6
# 44      44  0.970768                 71                 3
# 26      26  0.970768                 97                 4
#
#     params_learning_rate  params_n_estimators  params_min_child_samples  \
# 22              0.153321                  364                        89
# 15              0.160120                  270                        86
# 46              0.140477                  476                        72
# 24              0.146626                  348                        93
# 23              0.148114                  436                        81
# 43              0.244815                  415                        82
# 6               0.288884                  420                        73
# 25              0.108607                  283                        81
# 44              0.297668                  381                        12
# 26              0.202539                  199                        94
#
#     params_subsample  params_colsample_bytree
# 22          0.795334                 0.528601
# 15          0.869173                 0.553172
# 46          0.830552                 0.588859
# 24          0.789621                 0.645962
# 23          0.792011                 0.631951
# 43          0.728190                 0.615414
# 6           0.824394                 0.607387
# 25          0.701083                 0.548179
# 44          0.902042                 0.653608
# 26          0.744044                 0.630390

# %% [markdown]
# ### Conclusion
#
# Please, write down your thoughts on the experiment results:
#
#
# **Лучшие параметры:**
# - `num_leaves`: **117**
# - `max_depth`: **4**
# - `learning_rate`: **0.1533**
# - `n_estimators`: **364**
# - `min_child_samples`: **89**
# - `subsample`: **0.7953**
# - `colsample_bytree`: **0.5286**
#
# **Лучшая accuracy:** **97.55%**
#
# **Вывод:**
#
# Модель показала высокую accuracy, что свидетельствует о хорошем подборе гиперпараметров. Умеренная глубина деревьев и размер листьев позволили избежать переобучения, а комбинация параметров `learning_rate` и `n_estimators` обеспечила баланс между скоростью обучения и качеством.

# %% [markdown]
# ## Part 3. Interpret the model predictions
#
# Please use [shap](https://github.com/slundberg/shap) to build some plots and try to interpret them.

# %%
# !pip install shap
# Out:
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.46.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.6)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.10/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (3.1.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)

# %%
import shap  # noqa: F401

# %% [markdown]
# Сохраним лучшую модель из части 2:

# %%
best_model_params = study.best_params
best_model = lgb.LGBMClassifier(**best_model_params, verbose=-1)
best_model.fit(X_train_opt, y_train_opt)
# Out:
# LGBMClassifier(colsample_bytree=0.5286009853818954,
#                learning_rate=0.15332096295468947, max_depth=4,
#                min_child_samples=89, n_estimators=364, num_leaves=117,
#                subsample=0.7953343128961083, verbose=-1)

# %% [markdown]
# SHAP Explainer:

# %%
explainer = shap.Explainer(best_model)
shap_values = explainer.shap_values(X_test_pca)

# %% [markdown]
# Проверим количество классов:

# %%
num_classes = shap_values.shape[1] if len(shap_values.shape) > 2 else 1
print("Распознанное количество классов:", num_classes)

shap_values_mean = shap_values.mean(axis=2)
# Out:
# Распознанное количество классов: 179

# %% [markdown]
# Глобальная важность признаков:

# %%
print("Summary Plot (Bar) - Averaged SHAP values across classes")
shap.summary_plot(shap_values_mean, X_test_pca, plot_type="bar")
plt.show()
# Out:
# Summary Plot (Bar) - Averaged SHAP values across classes

# %% [markdown]
# Распределение значений SHAP:

# %%
print("Summary Plot (Distribution) - Averaged SHAP values across classes")
shap.summary_plot(shap_values_mean, X_test_pca)
plt.show()
# Out:
# Summary Plot (Distribution) - Averaged SHAP values across classes

# %% [markdown]
# Влияние конкретного признака на предсказания:

# %%
feature_to_plot = 0  # Можно заменить на индекс интересующего признака
print(f"Dependence Plot - Feature {feature_to_plot} - Averaged SHAP values")
shap.dependence_plot(feature_to_plot, shap_values_mean, X_test_pca)
plt.show()
# Out:
# Dependence Plot - Feature 0 - Averaged SHAP values

# %% [markdown]
# Индивидуальное объяснение для одного примера:

# %%
sample_index = 0  # Можно заменить на индекс интересующего признака
print(f"Force Plot for example {sample_index} - Averaged SHAP values")
shap.initjs()
expected_value_mean = np.mean(explainer.expected_value)
shap.force_plot(expected_value_mean, shap_values_mean[sample_index], X_test_pca[sample_index])
# Out:
# Force Plot for example 0 - Averaged SHAP values
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='iBCXNYYLIUKWWTBPNV7Q2'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": -7.986697325147006, "outValue": -9.726018062255617, "link": "identity", "featureNames": [-9.96803535389927, -1.779872952554455, -1.847173634872173, -1.4333404336339153, -3.7549478610675973, -0.16530358567275116, 3.613751617206815, -1.592361709900487, -2.6483774046958133, 0.36753415714941906, -1.407527580333825, -1.7369775384437447, 0.5922224409917841, -1.103543842857951, -1.737924055483296, -2.9490234331496237, 0.0729812424737368, 0.8405793035567347, 2.6375272331489157, 1.053429987127922, -2.4230604886595324, -0.8152495387776191, -0.0912931744834557, 0.6138756167754185, -1.1152525523320793, 3.291158390622436, -0.46181862756394293, 1.8786535997775093, 2.123840428459446, 2.7904585266291737, -1.35231050676023, -0.08414945750413362, 0.17583676948872384, 1.4621400786412828, -0.03562101787410844, -0.4791517098662891, 1.3963902478743886, 1.2304910174711226, -0.017169911530181173, -0.8877268416026095, -1.7891276524400503, 0.6710012684271129, 1.4010127042812215, 1.3087296316349315, -0.3467751471000319, -1.5753190700763187, -0.977932568032326, -1.2455711958176872, 0.5360871851503906, 2.062030958565647, -0.3642850866640246, 3.0428987179725144, -1.4553757977109134, 1.1006103919118986, -0.19616742346575497, -1.0474386010158228, 0.32391241399307824, -0.12547609333619048, 2.273980450402005, 0.5501977228571872, 0.387504416627282, 0.19236351195765447, -0.8235599350650817, -0.5710819610291527, -1.288992812182331, -1.0512384285245047, 1.675114453299972, -0.3808719785786866, 0.294677755513673, 0.27567962577410915, 0.6365490528730118, -1.0109468106314436, -0.4056148670510757, -1.186185496227607, 1.7667199152826545, 0.6016902491247108, -2.0690397041261197, -0.9539452973004842, -0.9314798374748948, 1.2876095686931253, 0.9508098626678105, -0.3223913065194872, 0.04694439363641127, 0.8839828471528337, -0.9447457271620631, -0.2051948602149539, -0.414561959322823, 0.3588674140959526, -1.191345730676974, -0.10849515524761906, 0.2775215898435489, 1.0251636060088107, 0.1632349537095786, 0.8178777155498151, 0.3023211027174132, 0.30111905839546926, -0.2632401358538643, 0.202249706139394, 0.4408922465406847, -0.2073088024264503, 1.465031311758542, -0.3805214128785072, 0.8875928157431209, 0.5858911909748444, -0.9279871153410891, 0.2609525037403659, 0.23778924981557875, 1.0399797026446875, -0.7897743668481628, 0.14583885637464652, 0.9092266517618854, -0.13733003642984154, -1.8337584519856347, 0.22062467532035254, 0.25203783076296393, -0.017284917966986814, 0.9899894394018238, -0.08818455981476693, -0.2531967109878836, -0.7061067758866304, 0.04783053561579583, -0.8155627376861421, 0.22413682241893323, 0.6364068605987675, 0.36457450962620763, 1.0175729147667176, 0.12791150833466333, 0.03293071512838823, -0.027963477478996027, -0.05151706343682349, -0.6405709967050129, -0.23778527375949, 1.033965633797007, -0.425302252999017, -0.5927759024404828, -0.5717408253496188, 0.15146879763938564, -0.08131959218835613, -0.36650334895375797, 0.3436053563872908, -0.8062908761796257, 0.8201389553426611, -0.5807968153059981, -0.3179477575967536, 0.7654942960978264, -0.34554601837673926, 1.1497556783029679, 0.588485464201114, -0.5219084570228196, -0.049471058293531676, 0.4504061440811754, -0.3439271648583133, 0.35310110843830783, 0.24633563837828193, 0.34582843541622343, -0.5388533697231656, -0.5815885968925215, 0.15676456522638776, -0.5861384694867113, -0.009916647916932517, 0.007222273688417661, 0.16597526153587425, -0.6393568578649093, -0.38597665344500587, 0.8628256857626883, 0.6620563865526367, 0.12011439547735633, 0.22635460525266005, -0.04924924873248511, -0.5860029940835766, 0.10787137877858768, 0.3032532250444497, 0.09379483239033132, 0.042306137235813605, 0.0957976981437661, 0.06881605450037447, 0.28608347830545483, -0.6855165757978477, 0.21085554251569252], "features": {"0": {"effect": -1.119678507971516, "value": ""}, "1": {"effect": 0.09246365429227886, "value": ""}, "2": { ...

# %% [markdown]
# ### Conclusion
#
# Your thoughts about the plots and model behaviour:
#
# 1. **Ключевые признаки**:
#    Feature 0 оказался самым значимым для модели, с большим отрывом по важности. За ним следуют Feature 3, Feature 4, Feature 1 и Feature 2. Их влияние подтверждает сильную зависимость целевой переменной от этих признаков.
#
# 2. **Глобальная интерпретация**:
#    Распределение SHAP-значений показало наличие кластеров данных и сложных нелинейных зависимостей. Feature 0 особенно выделяется своей ключевой ролью в определении результата модели.
#
# 3. **Локальная интерпретация**:
#    Индивидуальные объяснения для конкретных наблюдений (Force Plot) помогают понять, какие признаки вносят наибольший вклад в предсказания. Dependence Plot для Feature 0 выявил сложные зависимости, которые модель эффективно улавливает.
#
# 4. **Заключение**:
#    Модель демонстрирует стабильное поведение с интерпретируемыми результатами. Однако важность Feature 0 требует дополнительного анализа, чтобы понять его влияние в контексте задачи.
